# %%
# combined data exploration and visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import matplotlib.colors as mcolors
matplotlib.style.use('seaborn-whitegrid')
pd.set_option("display.max_columns", None)

# %%
# reading data combined data 
df=pd.read_csv("/Users/yelizce/code/burakonurlu/best_restaurant_location/best_restaurant_location/data/data_combined_v1.00.csv")

# %%
df.head()
# Out:
#                       place_id  tripadvisor_id                    fsq_id  \
# 0  ChIJd6kh67ZkjEcRC1IQourQOyo       7159041.0  4de685281f6e9d90c7f5325c
# 1  ChIJX68uubZkjEcRKKxpZ7OrgqU      13322506.0                       NaN
# 2  ChIJPcYsG_BljEcR4kTFqBJJoK4       6720272.0                       NaN
# 3  ChIJhb4e-Ep7jEcRY38kziIGZmE             NaN                       NaN
# 4  ChIJV8uySFxljEcRn7XpIO3zZX0             NaN                       NaN
#
#                               name business_status  \
# 0          Restaurant La Tentation     OPERATIONAL
# 1            Café Restaurant Palma     OPERATIONAL
# 2                    Le Versailles     OPERATIONAL
# 3                 Restaurant Divan     OPERATIONAL
# 4  Restaurant Les Jardins du Rhône     OPERATIONAL
#
#                                                types  price_level  \
# 0  ['restaurant', 'point_of_interest', 'food', 'e...          2.0
# 1  ['restaurant', 'point_of_interest', 'food', 'e...          NaN
# ...

# %%
# use main_category_1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1613 entries, 0 to 1612
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   place_id                       1613 non-null   object
#  1   tripadvisor_id                 959 non-null    float64
#  2   fsq_id                         677 non-null    object
#  3   name                           1613 non-null   object
#  4   business_status                1613 non-null   object
#  5   types                          1613 non-null   object
#  6   price_level                    592 non-null    float64
#  7   ta_price_level                 791 non-null    float64
#  8   rating                         1393 non-null   float64
#  9   user_ratings_total             1393 non-null   float64
#  10  ta_rating                      896 non-null    float64
#  11  ta_user_ratings_total          896 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['place_id', 'tripadvisor_id', 'fsq_id', 'name', 'business_status',
#        'types', 'price_level', 'ta_price_level', 'rating',
#        'user_ratings_total', 'ta_rating', 'ta_user_ratings_total',
#        'combined_rating', 'geometry.location.lat', 'geometry.location.lng',
#        'formatted_address', 'zip_code', 'city', 'international_phone_number',
#        'website', 'google_category', 'ta_4sq_cuisine1', 'ta_4sq_cuisine2',
#        'ta_4sq_cuisine3', 'ta_4sq_cuisine4', 'ta_4sq_cuisine5',
#        'main_category_1', 'main_category_2', 'main_category_3',
#        'main_category_4', 'combined_main_category', 'sub_category',
#        'neighboorhood_area_km2', 'resident_population_total',
#        'population_age_0_14', 'population_15_19', 'population_20_24',
#        'population_25_34', 'population_35_44', 'population_45_54',
#        'population_54_64', 'population_65+', 'resident_per_km2',
#        'brut_income_annual_per_person', 'cluster'],
#       dtype='object')

# %%
df.describe()
# Out:
#        tripadvisor_id  price_level  ta_price_level       rating  \
# count    9.590000e+02   592.000000      791.000000  1393.000000
# mean     9.955535e+06     1.959459        1.969659     4.298126
# std      7.577631e+06     0.534791        0.449010     0.494695
# min      6.978320e+05     1.000000        1.000000     1.000000
# 25%      3.393660e+06     2.000000        2.000000     4.100000
# 50%      8.308648e+06     2.000000        2.000000     4.300000
# 75%      1.531068e+07     2.000000        2.000000     4.600000
# max      2.486194e+07     4.000000        3.000000     5.000000
#
#        user_ratings_total   ta_rating  ta_user_ratings_total  combined_rating  \
# count         1393.000000  896.000000             896.000000      1416.000000
# mean           194.832735    4.032924             103.012277         4.265325
# std            385.398577    0.626936             204.095078         0.479021
# ...

# %%
df3=df[['combined_main_category', "rating",
       'population_age_0_14', 'population_15_19', 'population_20_24',
       'population_25_34', 'population_35_44', 'population_45_54',
       'population_54_64', 'population_65+', 'resident_per_km2',
       'brut_income_annual_per_person', 'cluster']]

# %%
sns.pairplot(df3, height=2)
plt.show()

# %%
df3.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>,
#         <AxesSubplot:title={'center':'population_age_0_14'}>,
#         <AxesSubplot:title={'center':'population_15_19'}>],
#        [<AxesSubplot:title={'center':'population_20_24'}>,
#         <AxesSubplot:title={'center':'population_25_34'}>,
#         <AxesSubplot:title={'center':'population_35_44'}>],
#        [<AxesSubplot:title={'center':'population_45_54'}>,
#         <AxesSubplot:title={'center':'population_54_64'}>,
#         <AxesSubplot:title={'center':'population_65+'}>],
#        [<AxesSubplot:title={'center':'resident_per_km2'}>,
#         <AxesSubplot:title={'center':'brut_income_annual_per_person'}>,
#         <AxesSubplot:title={'center':'cluster'}>]], dtype=object)

# %%
df[" population_20_24 "].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.13/envs/best_restaurant_location/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.pyenv/versions/3.8.13/envs/best_restaurant_location/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.13/envs/best_restaurant_location/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
sns.countplot(x='cluster', hue='rating', data=df)
plt.title("Cluster & Rating")

# %%
df.cluster.unique()

# %%
df["rating"]

# %%
sns.countplot(x='cluster', hue='rating', data=df)
plt.title("Cluster & Rating Distribution")
# Out:
# Text(0.5, 1.0, 'Cluster & Rating Distribution')

# %% [markdown]
# df[df["rating"]<=1]=1
# df[(df["rating"]>1) &(df["rating"]<=2)]=2
# df[(df["rating"]>2) &(df["rating"]<=3)]=3
# df[(df["rating"]>3) &(df["rating"]<=4)]=4
# df[(df["rating"]>4) &(df["rating"]<=5)]=5
#
#
# sns.countplot(x='cluster', hue='rating', data=df)
# plt.title("Cluster & Rating")

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='cluster', hue='resident_population_total', data=df)
plt.title("Cluster & Population Distribution")
# Out:
# Text(0.5, 1.0, 'Cluster & Population Distribution')

# %%
df4=df[['resident_population_total',
       'population_age_0_14', 'population_15_19', 'population_20_24',
       'population_25_34', 'population_35_44', 'population_45_54',
       'population_54_64', 'population_65+', 'resident_per_km2',
     'cluster']]

# %%
df4.head()

# %%
df4_C1=df4[df4.cluster==1]
df4_C2=df4[df4.cluster==2]
df4_C3=df4[df4.cluster==3]
df4_C4=df4[df4.cluster==4]

# %%
df.head()

# %%
df_categories = pd.DataFrame()
df_categories["restaurant_category"] = df[['main_category_1',
                                               'main_category_2',
                                                'main_category_3',
                                               'main_category_4']]\
                                                .apply(pd.Series.value_counts)\
                                                .sum(axis=1)\
                                                .sort_values(ascending=False)\
                                                .astype(int)

# %%
df_categories
# Out:
#                                         restaurant_category
# General / Restaurant                                    314
# European                                                203
# French                                                  191
# Italian                                                 166
# General / Fast food, Snacks, Take Away                  130
# Pizza                                                    94
# Swiss                                                    92
# General / Bar, Pub, Bistro                               89
# Japanese                                                 78
# General / Café                                           61
# Thai                                                     54
# Chinese                                                  52
# American                                                 47
# Hamburger                                                40
# Lebanese                                                 37
# ...

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='rating', data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
sns.countplot(x='price_level', data=df)
# Out:
# <AxesSubplot:xlabel='price_level', ylabel='count'>

# %%
fig = plt.figure(figsize=(12,3))
sns.countplot(x='rating', hue='price_level', data=df)
plt.title("Rating & Price Level Distribution")
# Out:
# Text(0.5, 1.0, 'Rating & Price Level Distribution')

# %%
sns.catplot(x='price_level', y='rating', data=df)

# %%
plt.figure(figsize=(20,4))
sns.catplot(x='rating', y='price_level', data=df)

# %%
df.rating.unique()
# Out:
# array([ 5.,  4., nan,  3.,  1.,  2.])

# %%
df.columns
# Out:
# Index(['place_id', 'tripadvisor_id', 'fsq_id', 'name', 'business_status',
#        'types', 'price_level', 'ta_price_level', 'rating',
#        'user_ratings_total', 'ta_rating', 'ta_user_ratings_total',
#        'combined_rating', 'geometry.location.lat', 'geometry.location.lng',
#        'formatted_address', 'zip_code', 'city', 'international_phone_number',
#        'website', 'google_category', 'ta_4sq_cuisine1', 'ta_4sq_cuisine2',
#        'ta_4sq_cuisine3', 'ta_4sq_cuisine4', 'ta_4sq_cuisine5',
#        'main_category_1', 'main_category_2', 'main_category_3',
#        'main_category_4', 'combined_main_category', 'sub_category',
#        'neighboorhood_area_km2', 'resident_population_total',
#        'population_age_0_14', 'population_15_19', 'population_20_24',
#        'population_25_34', 'population_35_44', 'population_45_54',
#        'population_54_64', 'population_65+', 'resident_per_km2',
#        'brut_income_annual_per_person', 'cluster'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4))
plt.scatter(df['zip_code'], df['resident_population_total'])

# %%
df5=df[['resident_population_total',
       'population_age_0_14', 'population_15_19', 'population_20_24',
       'population_25_34', 'population_35_44', 'population_45_54',
       'population_54_64', 'population_65+']]

# %%
plt.figure(figsize=(10,4))
plt.bar(df5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 2>()
#       1 plt.figure(figsize=(10,4))
# ----> 2 plt.bar(df5)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
df.columns
# Out:
# Index(['place_id', 'tripadvisor_id', 'fsq_id', 'name', 'business_status',
#        'types', 'price_level', 'ta_price_level', 'rating',
#        'user_ratings_total', 'ta_rating', 'ta_user_ratings_total',
#        'combined_rating', 'geometry.location.lat', 'geometry.location.lng',
#        'formatted_address', 'zip_code', 'city', 'international_phone_number',
#        'website', 'google_category', 'ta_4sq_cuisine1', 'ta_4sq_cuisine2',
#        'ta_4sq_cuisine3', 'ta_4sq_cuisine4', 'ta_4sq_cuisine5',
#        'main_category_1', 'main_category_2', 'main_category_3',
#        'main_category_4', 'combined_main_category', 'sub_category',
#        'neighboorhood_area_km2', 'resident_population_total',
#        'population_age_0_14', 'population_15_19', 'population_20_24',
#        'population_25_34', 'population_35_44', 'population_45_54',
#        'population_54_64', 'population_65+', 'resident_per_km2',
#        'brut_income_annual_per_person', 'cluster'],
#       dtype='object')

# %%
df["zip_code"].unique()
# Out:
# array([1203, 1213, 1219, 1216, 1209, 1205, 1202, 1227, 1201, 1204, 1224,
#        1207, 1292, 1206, 1208, 1214])

# %%
df_test=df[['zip_code','resident_population_total','google_category']].groupby(['zip_code'], sort = True)

# %%
category_distribution=pd.DataFrame(df_test.value_counts())
category_distribution
# Out:
#                                       0
# zip_code resident_population_total
# 1201     29787                      431
# 1202     20878                      122
# 1203     34002                       89
# 1204     8039                       253
# 1205     33448                      337
# 1206     19361                       36
# 1207     21169                      220
# 1208     16237                       16
# 1209     17091                       17
# 1213     34322                        5
# 1214     35778                        1
# 1216     35778                        2
# 1219     35778                        4
# 1224     13125                        3
# 1227     4772                        46
#          22727                       28
# 1292     3790                         3

# %%
newdf_votes=newdf_votes.filter(lambda x: x.mean() >= 175)
newdf_votes=newdf_votes.sort_values(by=['votes'])

# %%
df_cat=df[['google_category', 'ta_4sq_cuisine1', 'ta_4sq_cuisine2',
       'ta_4sq_cuisine3', 'ta_4sq_cuisine4', 'ta_4sq_cuisine5',
       'main_category_1', 'main_category_2', 'main_category_3',
       'main_category_4', 'combined_main_category', 'sub_category','zip_code','resident_population_total']].groupby(['zip_code'], sort=True)

# %%
df_cat.value_counts()
# Out:
# Series([], dtype: int64)

# %%
df6=df[['google_category', 'ta_4sq_cuisine1', 'ta_4sq_cuisine2',
       'ta_4sq_cuisine3', 'ta_4sq_cuisine4', 'ta_4sq_cuisine5',
       'main_category_1', 'main_category_2', 'main_category_3',
       'main_category_4', 'combined_main_category', 'sub_category','zip_code','resident_population_total']]

# %% [markdown]
# ## Suggestion for the column names for food category
#
# it can be restaurant type and cuisine

# %%
df6.head()
# Out:
#       google_category ta_4sq_cuisine1 ta_4sq_cuisine2 ta_4sq_cuisine3  \
# 0          Restaurant        European           Swiss   International
# 1          Restaurant               0               0               0
# 2  Italian restaurant         Italian          French   International
# 3          Restaurant               0               0               0
# 4          Restaurant               0               0               0
#
#   ta_4sq_cuisine4   ta_4sq_cuisine5       main_category_1 main_category_2  \
# 0               0                 0              European           Swiss
# 1               0                 0  General / Restaurant             NaN
# 2        European  Central European               Italian          French
# 3               0                 0  General / Restaurant             NaN
# 4               0                 0  General / Restaurant             NaN
#
#   main_category_3 main_category_4     combined_main_category sub_category  \
# ...

# %%
# restaurant type and cuisine
df6["google_category"].unique()
# Out:
# array(['Restaurant', 'Italian restaurant', 'Asian restaurant',
#        'Chicken restaurant', 'Swiss restaurant', 'Pizza takeaway',
#        'Portuguese restaurant', 'Pizza restaurant',
#        'Brazilian restaurant', 'Takeout Restaurant', 'Sushi restaurant',
#        'Bar & grill', 'Japanese restaurant', 'Tea house',
#        'Lebanese restaurant', 'Down home cooking restaurant',
#        'Colombian restaurant', 'Bakery', 'South American restaurant',
#        'Bar', 'Caterer', 'Fast food restaurant', 'Doner kebab restaurant',
#        'Indian restaurant', 'Spanish restaurant', 'Pizza delivery',
#        'Thai restaurant', 'Turkish restaurant', 'Kebab shop',
#        'Taco restaurant', 'Chinese restaurant', 'Sandwich shop',
#        'Brewery', 'Cafe', 'Takeout restaurant', 'Sri Lankan restaurant',
#        'Stand bar', 'Eritrean restaurant', 'Mexican restaurant',
#        'Irish pub', 'Argentinian restaurant', 'Indonesian restaurant',
# ...

# %%
df["main_category_1"].unique()
# Out:
# array(['European', 'General / Restaurant', 'Italian', 'Swiss', 'Japanese',
#        'Chinese', 'Chicken', 'General / Café', 'Pizza', 'Seafood',
#        'Portuguese', 'Steakhouse, Barbecue, Grill', 'South American',
#        'Hamburger', 'General / Fast food, Snacks, Take Away',
#        'General / Bar, Pub, Bistro', 'French', 'Lebanese', 'Turkish',
#        'Indian', 'Spanish', 'Thai', 'Other Middle Eastern', 'Mexican',
#        'Other Asian', 'Vegan, Vegetarian, Salad', 'African', 'Hawaiian',
#        'All Other', 'American', '0'], dtype=object)

# %%
df.head()
# Out:
#                       place_id  tripadvisor_id                    fsq_id  \
# 0  ChIJd6kh67ZkjEcRC1IQourQOyo       7159041.0  4de685281f6e9d90c7f5325c
# 1  ChIJX68uubZkjEcRKKxpZ7OrgqU      13322506.0                       NaN
# 2  ChIJPcYsG_BljEcR4kTFqBJJoK4       6720272.0                       NaN
# 3  ChIJhb4e-Ep7jEcRY38kziIGZmE             NaN                       NaN
# 4  ChIJV8uySFxljEcRn7XpIO3zZX0             NaN                       NaN
#
#                               name business_status  \
# 0          Restaurant La Tentation     OPERATIONAL
# 1            Café Restaurant Palma     OPERATIONAL
# 2                    Le Versailles     OPERATIONAL
# 3                 Restaurant Divan     OPERATIONAL
# 4  Restaurant Les Jardins du Rhône     OPERATIONAL
#
#                                                types  price_level  \
# 0  ['restaurant', 'point_of_interest', 'food', 'e...          2.0
# 1  ['restaurant', 'point_of_interest', 'food', 'e...          NaN
# ...

# %%
category=pd.DataFrame(df["google_category"].str.split(" ", expand=True))

# %%
category[0].unique
# Out:
# <bound method Series.unique of 0       Restaurant
# 1       Restaurant
# 2          Italian
# 3       Restaurant
# 4       Restaurant
#            ...
# 1608        Bakery
# 1609      American
# 1610         Swiss
# 1611    Restaurant
# 1612    Restaurant
# Name: 0, Length: 1613, dtype: object>

# %% [markdown]
# restaurant type / cuisine
# https://www.kaggle.com/code/parthsharma5795/finding-the-best-restaurants-in-bangalore
