# %%
# required module import
import shapely.geometry as shg
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
# reading GVA district shape data and converting it to lat / lng format
df_district_shp = gpd.read_file('../raw_data/VDG_QUARTIER_VILLE.shp')
display(df_district_shp)
df_district_geo = soa_shape_map.to_crs(epsg=4326)
display(df_district_map_geo)
# Out:
#                 NOM_QUARTI    SHAPE_AREA    SHAPE_LEN  \
# 0    Grottes Saint-Gervais  1.150991e+06  6140.098504
# 1                  Champel  2.973580e+06  8560.806130
# 2          Pâquis Sécheron  2.222486e+06  9603.061056
# 3     Plainpalais Jonction  1.431242e+06  6622.571344
# 4          Eaux-Vives Cité  2.421590e+06  9253.853914
# 5            Acacias Bâtie  1.393098e+06  7714.654151
# 6  Servette Petit-Saconnex  2.225106e+06  6660.793422
# 7    Saint-Jean Charmilles  2.088505e+06  6289.548052
#
#                                             geometry
# 0  POLYGON ((2500043.640 1118560.700, 2500053.560...
# 1  POLYGON ((2501971.870 1117304.280, 2502141.340...
# 2  POLYGON ((2500209.450 1118410.180, 2500094.420...
# 3  POLYGON ((2499699.560 1116581.070, 2499676.540...
# 4  POLYGON ((2502457.280 1117727.440, 2502453.360...
# 5  POLYGON ((2499109.920 1117071.040, 2499170.450...
# 6  POLYGON ((2498982.570 1118873.840, 2498964.320...
# 7  POLYGON ((2499154.020 1117999.810, 2499178.400...
#                 NOM_QUARTI    SHAPE_AREA    SHAPE_LEN  \
# 0    Grottes Saint-Gervais  1.150991e+06  6140.098504
# 1                  Champel  2.973580e+06  8560.806130
# 2          Pâquis Sécheron  2.222486e+06  9603.061056
# 3     Plainpalais Jonction  1.431242e+06  6622.571344
# 4          Eaux-Vives Cité  2.421590e+06  9253.853914
# 5            Acacias Bâtie  1.393098e+06  7714.654151
# 6  Servette Petit-Saconnex  2.225106e+06  6660.793422
# 7    Saint-Jean Charmilles  2.088505e+06  6289.548052
#
#                                             geometry
# 0  POLYGON ((6.14340 46.21106, 6.14353 46.21100, ...
# 1  POLYGON ((6.16865 46.20004, 6.17084 46.20007, ...
# 2  POLYGON ((6.14558 46.20973, 6.14407 46.21054, ...
# 3  POLYGON ((6.13937 46.19320, 6.13906 46.19350, ...
# 4  POLYGON ((6.17484 46.20392, 6.17479 46.20387, ...
# 5  POLYGON ((6.13162 46.19752, 6.13242 46.19696, ...
# 6  POLYGON ((6.12958 46.21371, 6.12935 46.21380, ...
# 7  POLYGON ((6.13199 46.20588, 6.13231 46.20576, ...

# %%
# reading lat / lng from df and converting it to numpy array
df_rest = pd.read_csv('../data/data_combined_v1.01.csv')
df_rest.head()
# Out:
#    Unnamed: 0                     place_id  tripadvisor_id  \
# 0           0  ChIJd6kh67ZkjEcRC1IQourQOyo       7159041.0
# 1           1  ChIJX68uubZkjEcRKKxpZ7OrgqU      13322506.0
# 2           2  ChIJPcYsG_BljEcR4kTFqBJJoK4       6720272.0
# 3           3  ChIJhb4e-Ep7jEcRY38kziIGZmE             NaN
# 4           4  ChIJV8uySFxljEcRn7XpIO3zZX0             NaN
#
#                      fsq_id                             name business_status  \
# 0  4de685281f6e9d90c7f5325c          Restaurant La Tentation     OPERATIONAL
# 1                       NaN            Café Restaurant Palma     OPERATIONAL
# 2                       NaN                    Le Versailles     OPERATIONAL
# 3                       NaN                 Restaurant Divan     OPERATIONAL
# 4                       NaN  Restaurant Les Jardins du Rhône     OPERATIONAL
#
#                                                types  price_level  \
# 0  ['restaurant', 'point_of_interest', 'food', 'e...          2.0
# 1  ['restaurant', 'point_of_interest', 'food', 'e...          NaN
# 2  ['restaurant', 'point_of_interest', 'food', 'e...          NaN
# 3  ['restaurant', 'food', 'point_of_interest', 'e...          2.0
# 4  ['restaurant', 'food', 'point_of_interest', 'e...          NaN
#
#    ta_price_level  price_level_combined  ...  population_15_19  \
# 0             2.0                   3.0  ...              1547
# 1             NaN                   4.0  ...              1547
# 2             2.0                   3.0  ...              1547
# 3             NaN                   3.0  ...              1956
# 4             NaN                   NaN  ...              1547
#
#    population_20_24  population_25_34  population_35_44  population_45_54  \
# 0              1937              5163              5549              4924
# 1              1937              5163              5549              4924
# 2              1937              5163              5549              4924
# 3              2148              4721              5127              5017
# 4              1937              5163              5549              4924
#
#    population_54_64  population_65+ resident_per_km2  \
# 0              4290            5625            16282
# 1              4290            5625            16282
# 2              4290            5625            16282
# 3              3956            5342             7187
# 4              4290            5625            16282
#
#    brut_income_annual_per_person cluster
# 0                         109266       2
# 1                         109266       2
# 2                         109266       2
# 3                         123472       2
# 4                         109266       2
#
# [5 rows x 47 columns]

# %%
for idx_rest, row_rest in df_rest.iterrows():
    point = shg.Point(df_rest.loc[idx_rest,'geometry.location.lng'],\
                 df_rest.loc[idx_rest,'geometry.location.lat'])
    for idx_geo, row_geo in df_district_geo.iterrows():
        if point.within(df_district_geo.loc[idx_geo, 'geometry']):
            df_rest.loc[idx_rest, 'district'] = df_district_geo.loc[idx_geo, 'NOM_QUARTI']
            break

# %%
df_rest['district'].value_counts()
# Out:
# Eaux-Vives Cité            467
# Plainpalais Jonction       339
# Pâquis Sécheron            260
# Grottes Saint-Gervais      252
# Saint-Jean Charmilles       92
# Servette Petit-Saconnex     57
# Champel                     55
# Acacias Bâtie               49
# Name: district, dtype: int64

# %%
df_rest['district'].isnull().sum()
# Out:
# 42

# %%
# Sample Check 1
pointx = shg.Point((6.1561736, 46.1993241)) # Luigia in Eaux-Vives area
print(pointx.within(soa_shape_map_geo['geometry'][3])) # Plainpalais area
print(pointx.within(soa_shape_map_geo['geometry'][4])) # Eaux-Vives area
# Out:
# False
# True

# %%
# Sample Check 2
pointx = shg.Point((6.1361528, 46.1980208)) # Umamido in Plainpalais area
print(pointx.within(soa_shape_map_geo['geometry'][3])) # Plainpalais area
print(pointx.within(soa_shape_map_geo['geometry'][4])) # Eaux-Vives area
# Out:
# True
# False

# %%
df_rest.columns
# Out:
# Index(['Unnamed: 0', 'place_id', 'tripadvisor_id', 'fsq_id', 'name',
#        'business_status', 'types', 'price_level', 'ta_price_level',
#        'price_level_combined', 'rating', 'user_ratings_total', 'ta_rating',
#        'ta_user_ratings_total', 'combined_rating', 'geometry.location.lat',
#        'geometry.location.lng', 'formatted_address', 'zip_code', 'city',
#        'international_phone_number', 'website', 'google_category',
#        'ta_4sq_cuisine1', 'ta_4sq_cuisine2', 'ta_4sq_cuisine3',
#        'ta_4sq_cuisine4', 'ta_4sq_cuisine5', 'main_category_1',
#        'main_category_2', 'main_category_3', 'main_category_4',
#        'combined_main_category', 'sub_category', 'neighboorhood_area_km2',
#        'resident_population_total', 'population_age_0_14', 'population_15_19',
#        'population_20_24', 'population_25_34', 'population_35_44',
#        'population_45_54', 'population_54_64', 'population_65+',
#        'resident_per_km2', 'brut_income_annual_per_person', 'cluster',
#        'district'],
#       dtype='object')

# %%
# Final Processing
# Removal of Future Restaurants i.e. without restaurant category
df_rest = df_rest[(df_rest['combined_main_category'].notnull()) &\
                  (df_rest['district'].notnull())]\
                .reset_index(drop=True)
df_rest
# Out:
#       Unnamed: 0                     place_id  tripadvisor_id  \
# 0              0  ChIJd6kh67ZkjEcRC1IQourQOyo       7159041.0
# 1              1  ChIJX68uubZkjEcRKKxpZ7OrgqU      13322506.0
# 2              2  ChIJPcYsG_BljEcR4kTFqBJJoK4       6720272.0
# 3              4  ChIJV8uySFxljEcRn7XpIO3zZX0             NaN
# 4              5  ChIJW8zU8rZkjEcR_Ke8t7c7hVc             NaN
# ...          ...                          ...             ...
# 1564        1606  ChIJtW8VekZljEcRHMTm4W0SQoo      23982683.0
# 1565        1607  ChIJ8xcfO5JljEcRMsNfQ7YjlqM      23357178.0
# 1566        1608  ChIJhxG2srN6jEcRUls_UY7b5Io       6403958.0
# 1567        1609  ChIJHSzAC1JljEcRjr7q009gZe4        784992.0
# 1568        1612  ChIJL68o71FljEcRvXVtz35xl2A       8370681.0
#
#                         fsq_id                                      name  \
# 0     4de685281f6e9d90c7f5325c                   Restaurant La Tentation
# 1                          NaN                     Café Restaurant Palma
# 2                          NaN                             Le Versailles
# 3                          NaN           Restaurant Les Jardins du Rhône
# 4                          NaN  Canteen De La Residence Gardens Du Rhône
# ...                        ...                                       ...
# 1564                       NaN              Hôtel du Parc des Eaux-Vives
# 1565                       NaN                       La Terrasse du Parc
# 1566  5310fd59498eb11ab86b0443                             Le B d'Armand
# 1567                       NaN                               Road Runner
# 1568                       NaN                  Restaurant Les Tulipiers
#
#      business_status                                              types  \
# 0        OPERATIONAL  ['restaurant', 'point_of_interest', 'food', 'e...
# 1        OPERATIONAL  ['restaurant', 'point_of_interest', 'food', 'e...
# 2        OPERATIONAL  ['restaurant', 'point_of_interest', 'food', 'e...
# 3        OPERATIONAL  ['restaurant', 'food', 'point_of_interest', 'e...
# 4        OPERATIONAL  ['restaurant', 'food', 'point_of_interest', 'e...
# ...              ...                                                ...
# 1564     OPERATIONAL  ['restaurant', 'lodging', 'point_of_interest',...
# 1565     OPERATIONAL  ['restaurant', 'point_of_interest', 'food', 'e...
# 1566     OPERATIONAL  ['bakery', 'cafe', 'restaurant', 'food', 'poin...
# 1567     OPERATIONAL  ['restaurant', 'food', 'point_of_interest', 'e...
# 1568     OPERATIONAL  ['restaurant', 'point_of_interest', 'food', 'e...
#
#       price_level  ta_price_level  price_level_combined  ...  \
# 0             2.0             2.0                   3.0  ...
# 1             NaN             NaN                   4.0  ...
# 2             NaN             2.0                   3.0  ...
# 3             NaN             NaN                   NaN  ...
# 4             NaN             NaN                   4.0  ...
# ...           ...             ...                   ...  ...
# 1564          3.0             NaN                   4.0  ...
# 1565          NaN             3.0                   4.0  ...
# 1566          2.0             2.0                   3.0  ...
# 1567          2.0             2.0                   3.0  ...
# 1568          1.0             2.0                   2.0  ...
#
#       population_20_24  population_25_34  population_35_44  population_45_54  \
# 0                 1937              5163              5549              4924
# 1                 1937              5163              5549              4924
# 2                 1937              5163              5549              4924
# 3                 1937              5163              5549              4924
# 4                 1937              5163              5549              4924
# ...                ...               ...               ...               ...
# 1564               996              3839              3699              3048
# 1565               996              3839              3699              3048
# 1566               722              2175              2592              2309
# 1567               722              2175              2592              2309
# 1568               722              2175              2592              2309
#
#       population_54_64  population_65+  resident_per_km2  \
# 0                 4290            5625             16282
# 1                 4290            5625             16282
# 2                 4290            5625             16282
# 3                 4290            5625             16282
# 4                 4290            5625             16282
# ...                ...             ...               ...
# 1564              2638            3503             15694
# 1565              2638            3503             15694
# 1566              1850            3109             13812
# 1567              1850            3109             13812
# 1568              1850            3109             13812
#
#      brut_income_annual_per_person  cluster               district
# 0                           109266        2  Saint-Jean Charmilles
# 1                           109266        2  Saint-Jean Charmilles
# 2                           109266        2  Saint-Jean Charmilles
# 3                           109266        2  Saint-Jean Charmilles
# 4                           109266        2  Saint-Jean Charmilles
# ...                            ...      ...                    ...
# 1564                        132730        0        Eaux-Vives Cité
# 1565                        132730        0        Eaux-Vives Cité
# 1566                        177681        0                Champel
# 1567                        177681        0        Eaux-Vives Cité
# 1568                        177681        0        Eaux-Vives Cité
#
# [1569 rows x 48 columns]

# %%
df_rest.to_csv('../data/data_combined_v1.02.csv', encoding='utf-8-sig', index=False)
