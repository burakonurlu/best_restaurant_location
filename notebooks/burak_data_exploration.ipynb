# %%
# required modules
import pandas as pd
import numpy as np 
import matplotlib
# %matplotlib inline
matplotlib.style.use('default')

# %%
df = pd.read_csv('../raw_data/raw_data_combined_v1.02.csv')

# %%
df.head()
# Out:
#    original_index                     place_id  tripadvisor_id  \
# 0               0  ChIJd6kh67ZkjEcRC1IQourQOyo       7159041.0
# 1               1  ChIJX68uubZkjEcRKKxpZ7OrgqU      13322506.0
# 2               2  ChIJPcYsG_BljEcR4kTFqBJJoK4       6720272.0
# 3               4  ChIJhb4e-Ep7jEcRY38kziIGZmE             NaN
# 4               5  ChIJV8uySFxljEcRn7XpIO3zZX0             NaN
#
#                      fsq_id                             name business_status  \
# 0  4de685281f6e9d90c7f5325c          Restaurant La Tentation     OPERATIONAL
# 1                       NaN            Café Restaurant Palma     OPERATIONAL
# 2                       NaN                    Le Versailles     OPERATIONAL
# 3                       NaN                 Restaurant Divan     OPERATIONAL
# 4                       NaN  Restaurant Les Jardins du Rhône     OPERATIONAL
#
#                                                types  price_level  \
# ...

# %%
missing_values = df.isnull().sum() / len(df) * 100

# %%
missing_values
# Out:
# original_index                 0.000000
# place_id                       0.000000
# tripadvisor_id                44.090382
# fsq_id                        60.139050
# name                           0.000000
# business_status                0.000000
# types                          0.000000
# price_level                   66.512167
# ta_price_level                54.403244
# rating                        18.076477
# user_ratings_total            18.076477
# ta_rating                     47.740440
# ta_user_ratings_total         47.740440
#  combined_rating              16.628042
# geometry.location.lat          0.000000
# geometry.location.lng          0.000000
# formatted_address              0.000000
# zip_code                       0.000000
# city                           0.000000
# international_phone_number     0.000000
# website                       56.720742
# combined_cuisine_type         37.485516
# ta_4sq_cuisine1                0.347625
# ...

# %%
df2 = pd.read_csv('../raw_data/phantombuster_v2_conversion_trial.csv')

# %%
df2.head()
# Out:
#                                             placeUrl  \
# 0  https://www.google.com/maps/place/%22Chez+Pepp...
# 1  https://www.google.com/maps/place/%22INCA'S+BA...
# 2  https://www.google.com/maps/place/10+Dieci+Piz...
# 3  https://www.google.com/maps/place/dieci+Pizza+...
# 4  https://www.google.com/maps/place/dieci+Pizza+...
#
#                                   title rating  reviewCount          category  \
# 0        "Chez Peppino", Pinto Giuseppe    4.1         42.0  Pizza restaurant
# 1                          "INCA'S BAR"    3.9          8.0         Snack bar
# 2  10 Dieci Pizza Livraison & Take Away    NaN          NaN        Restaurant
# 3           dieci Pizza Genève Servette    4.2         73.0    Pizza delivery
# 4         dieci Pizza Genève Eaux-Vives    4.3        136.0    Pizza delivery
#
#                                           attributes  \
# 0             ¬∑  Dine-in  ¬∑  Takeout  ¬∑  Delivery
# 1             ¬∑  Dine-in  ¬∑  Takeout  ¬∑  Delivery
# ...

# %%
df2.to_csv('../raw_data/conversion_trial.csv', encoding='utf-8-sig')
